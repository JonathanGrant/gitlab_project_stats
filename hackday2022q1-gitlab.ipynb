# %%
# !pip install python-gitlab
# Docs: https://python-gitlab.readthedocs.io/en/stable/api-usage.html
# !pip install beautifulsoup4
# Docs: https://www.crummy.com/software/BeautifulSoup/bs4/doc/
# Out:
# Requirement already satisfied: python-gitlab in c:\users\jonathan\anaconda3\lib\site-packages (3.2.0)
# Requirement already satisfied: requests-toolbelt>=0.9.1 in c:\users\jonathan\anaconda3\lib\site-packages (from python-gitlab) (0.9.1)
# Requirement already satisfied: requests>=2.25.0 in c:\users\jonathan\anaconda3\lib\site-packages (from python-gitlab) (2.26.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\jonathan\anaconda3\lib\site-packages (from requests>=2.25.0->python-gitlab) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\jonathan\anaconda3\lib\site-packages (from requests>=2.25.0->python-gitlab) (1.26.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\jonathan\anaconda3\lib\site-packages (from requests>=2.25.0->python-gitlab) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\jonathan\anaconda3\lib\site-packages (from requests>=2.25.0->python-gitlab) (3.2)
# Requirement already satisfied: beautifulsoup4 in c:\users\jonathan\anaconda3\lib\site-packages (4.10.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\jonathan\anaconda3\lib\site-packages (from beautifulsoup4) (2.2.1)

# %%
#Imports in one place to not cloud up work
import requests
import gitlab
from bs4 import BeautifulSoup
import functools
import re
import time
import random
import json
import concurrent.futures

# %%
#https://gitlab.com/explore/projects/starred
# Get top n starred projects. 
# Gitlab API does not support this, so we must use web-scraping

# Caching to avoid rate limiting
@functools.cache
def get_https_text(url):
    return requests.get(url).text

def get_starred_projects_html(page_num):
    return get_https_text(f"https://gitlab.com/explore/projects/starred?sort=stars_desc&page={page_num}")

# %%
projects = []
for page in range(1, 50):  # 50 is the max page
    r = get_starred_projects_html(page)
    good_soup = BeautifulSoup(r, 'html.parser')  # https://www.youtube.com/watch?v=gkXzeZ0KE5Q
    projects.extend(good_soup.find_all("li", {"class": 'project-row'}))
    time.sleep(0.5)  # Dont get rate-limited by gitlab

# %%
# Turn div into project dict
non_number_re = re.compile('[^0-9]')
def extract_proj_details(proj):
    return {
        'name': proj.find('span', {'class': 'project-name'}).text,
        'namespace': proj.find('span', {'class': 'namespace-name'}).text[:-3].strip(),
        'url': proj.find('a').attrs['href'],
        # Following are possible to get from here but better to get from api as they are not always in html
#             'stars': int(non_number_re.sub('', proj.find('a', {'title': 'Stars'}).text)),
#             'forks': int(non_number_re.sub('', proj.find('a', {'title': 'Forks'}).text)),
    }
extract_proj_details(projects[0])
# Out:
# {'name': 'GitLab FOSS',
#  'namespace': 'GitLab.org',
#  'url': '/gitlab-org/gitlab-foss'}

# %%
top_projects = [extract_proj_details(proj) for proj in projects]
len(top_projects), top_projects[:5]
# Out:
# (400,
#  [{'name': 'GitLab FOSS',
#    'namespace': 'GitLab.org',
#    'url': '/gitlab-org/gitlab-foss'},
#   {'name': 'GitLab', 'namespace': 'GitLab.org', 'url': '/gitlab-org/gitlab'},
#   {'name': 'inkscape', 'namespace': 'Inkscape', 'url': '/inkscape/inkscape'},
#   {'name': 'OpenRGB',
#    'namespace': 'Adam Honse',
#    'url': '/CalcProgrammer1/OpenRGB'},
#   {'name': 'gitlab-runner',
#    'namespace': 'GitLab.org',
#    'url': '/gitlab-org/gitlab-runner'}])

# %%
def extract_gl_data_from_project(proj):
    gl = gitlab.Gitlab()
    time.sleep(random.randint(1, 10))  # Give gitlab a little break
    access_time = time.time()
    gl_proj = gl.projects.get(proj['url'][1:])
    proj_data = gl_proj.attributes
    proj_data['access_time'] = access_time
    groups = gl_proj.groups.list()
    # Sometimes get an authentication error depending on project, easier to except all instead of the right error
    try:
        proj_data['groups'] = [group.attributes for group in gl_proj.groups.list(all=True)]
    except:
        pass
    try:
        proj_data['languages'] = gl_proj.languages()
    except:
        pass
    try:
        proj_data['issue_stats'] = gl_proj.issues_statistics.get().attributes['statistics']
    except:
        pass
    try:
        proj_data['top_20_repository_contibutors'] = gl_proj.repository_contributors(per_page=20, order_by='commits', sort='desc')
    except:
        pass
    
    # get branch/commit/tag counts through requests and bs4 as its not in gitlab api
    proj_page_text = get_https_text(f'https://gitlab.com{proj["url"]}')
    good_soup = BeautifulSoup(proj_page_text, 'html.parser')
    soup_stats = good_soup.find('nav', {'class': 'project-stats'})
    if soup_stats is not None:
        soup_stats = [x.text for x in soup_stats.find_all('strong', {'class': 'project-stat-value'})]
        for stat_name, stat_value in zip(['commits', 'branches', 'tags', 'files', 'storage', 'releases'], soup_stats):
            proj_data[f'from_page_stats_{stat_name}'] = stat_value
        
    # Get MR stats through requests & bs4 as its not in api
    mr_page_text = get_https_text(f'https://gitlab.com{proj["url"]}/-/merge_requests')
    good_soup = BeautifulSoup(mr_page_text, 'html.parser')
    for mr_state in ['opened', 'merged', 'closed', 'all']:
        if state_data := good_soup.find('a', {'id': f'state-{mr_state}'}):
            proj_data[f'num_merge_requests_{mr_state}'] = int(non_number_re.sub('', state_data.find_all('span')[-1].text))

    # Save raw data too
    proj_data['html'] = {
        'main': {
            'url': f'https://gitlab.com{proj["url"]}',
            'html': proj_page_text,
        },
        'merge_requests': {
            'url': f'https://gitlab.com{proj["url"]}/-/merge_requests',
            'html': mr_page_text,
        }
    }

    return proj_data

# %%
# Thread and not Process because network bound not CPU bound
with concurrent.futures.ThreadPoolExecutor() as ex:
    all_data = list(ex.map(extract_gl_data_from_project, top_projects))

# %%
len(all_data), all_data[-5:]
# Out:
# (400,
#  [{'id': 20975946,
#    'description': 'Découvrez les tutoriels ansible en français ici : https://youtu.be/kzmvwc2q_z0',
#    'name': 'Tutoriels Ansible',
#    'name_with_namespace': 'Xavier / Tutoriels Ansible',
#    'path': 'presentation-ansible-fr',
#    'path_with_namespace': 'xavki/presentation-ansible-fr',
#    'created_at': '2020-09-07T08:03:28.393Z',
#    'default_branch': 'master',
#    'tag_list': ['ansible', 'docker'],
#    'topics': ['ansible', 'docker'],
#    'ssh_url_to_repo': 'git@gitlab.com:xavki/presentation-ansible-fr.git',
#    'http_url_to_repo': 'https://gitlab.com/xavki/presentation-ansible-fr.git',
#    'web_url': 'https://gitlab.com/xavki/presentation-ansible-fr',
#    'readme_url': 'https://gitlab.com/xavki/presentation-ansible-fr/-/blob/master/README.md',
#    'avatar_url': 'https://gitlab.com/uploads/-/system/project/avatar/20975946/Ansible_logo-700x700.png',
#    'forks_count': 32,
#    'star_count': 43,
#    'last_activity_at': '2022-01-14T16:44:29.733Z',
#    'namespace': {'id': 3908943,
#     'name': 'Xavier',
#     'path': 'xavki',
#     'kind': 'user',
#     'full_path': 'xavki',
#     'parent_id': None,
#     'avatar_url': '/uploads/-/system/user/avatar/3063067/avatar.png',
#     'web_url': 'https://gitlab.com/xavki'},
#    'access_time': 1647632129.574384,
#    'groups': [],
#    'languages': {'HTML': 45.25,
#     'Ruby': 26.14,
#     'Python': 19.23,
#     'Shell': 7.82,
#     'Makefile': 0.85},
#    'issue_stats': {'counts': {'all': 1, 'closed': 0, 'opened': 1}},
#    'top_20_repository_contibutors': [{'name': 'xavki',
#      'email': 'xavki@moi.me',
#      'commits': 132,
#      'additions': 0,
#      'deletions': 0},
#     {'name': 'oki',
#      'email': 'Xavier Pestel',
#      'commits': 18,
#      'additions': 0,
#      'deletions': 0},
#     {'name': 'xpestel',
#      'email': 'xpestel@weborama.com',
#      'commits': 4,
#      'additions': 0,
#      'deletions': 0},
#     {'name': 'Romain',
#      'email': '3678934-Rom1deTroyes@users.noreply.gitlab.com',
#      'commits': 1,
#      'additions': 0,
#      'deletions': 0},
#     {'name': 'Xavier',
#      'email': 'xavier.pestel@gmail.com',
#      'commits': 1,
#      'additions': 0,
#      'deletions': 0}],
#    'from_page_stats_commits': '158',
#    'from_page_stats_branches': '1',
#    'from_page_stats_tags': '0',
#    'from_page_stats_files': '25.8 MB',
#    'from_page_stats_storage': '25.8 MB',
#    'num_merge_requests_opened': 4,
#    'num_merge_requests_merged': 1,
#    'num_merge_requests_closed': 0,
#    'num_merge_requests_all': 5,
#    'html': {'main': {'url': 'https://gitlab.com/xavki/presentation-ansible-fr',
#      'html': '<!DOCTYPE html>\n<html class="" lang="en">\n<head prefix="og: http://ogp.me/ns#">\n<meta charset="utf-8">\n<link rel="preload" href="/assets/application_utilities-79bc2841975b0e515219eb7a828208ace79b8c07d0536e809746db7e22deeaab.css" as="style" type="text/css" nonce="ZgoZjD9g4Kujx4+ljBovCQ==">\n<link rel="preload" href="/assets/application-6eb5eaa5726150b8135a4fd09118cfd6b29f128586b7fa5019a04f1c740e9193.css" as="style" type="text/css" nonce="ZgoZjD9g4Kujx4+ljBovCQ==">\n<link rel="preload" href="/assets/highlight/themes/white-14ba9f209d5cc375d065606896b08ef3d4dc7be19e5b5800958b390d7ab2bd40.css" as="style" type="text/css" nonce="ZgoZjD9g4Kujx4+ljBovCQ==">\n<link crossorigin="" href="snowplow.trx.gitlab.net" rel="preconnect">\n\n<meta content="IE=edge" http-equiv="X-UA-Compatible">\n<script nonce="Ruac6vP8Ve6rZTGgVPblfA==">\n//<![CDATA[\nvar gl = window.gl || {};\ngl.startup_calls = {"/xavki/presentation-ansible-fr/-/refs/master/logs_tree/?format=json\\u0026offset=0":{},"/xavki/presentation-ansible-fr/-/blob/master/README.md?format=json\\u0026viewer=rich":{}};\ngl.startup_graphql_calls = [{"query":"query pathLastCommit($projectPath: ID!, $path: String, $ref: String!) {\\n  project(fullPath: $projectPath) {\\n    __typename\\n    id\\n    repository {\\n      __typename\\n      tree(path: $path, ref: $ref) {\\n        __typename\\n        lastCommit {\\n          __typename\\n          id\\n          sha\\n          title\\n          titleHtml\\n          descriptionHtml\\n          message\\n          webPath\\n          authoredDate\\n          authorName\\n          authorGravatar\\n          author {\\n            __typename\\n            id\\n            name\\n            avatarUrl\\n            webPath\\n          }\\n          signatureHtml\\n          pipelines(ref: $ref, first: 1) {\\n            __typename\\n            edges {\\n              __typename\\n              node {\\n                __typename\\n                id\\n                detailedStatus {\\n                  __typename\\n                  id\\n                  detailsPath\\n                  icon\\n                  tooltip\\n                  text\\n                  group\\n                }\\n              }\\n            }\\n          }\\n        }\\n      }\\n    }\\n  }\\n}\\n","variables":{"projectPath":"xavki/presentation-ansible-fr","ref":"master","path":""}}];\n\nif (gl.startup_calls && window.fetch) {\n  Object.keys(gl.startup_calls).forEach(apiCall => {\n   gl.startup_calls[apiCall] = {\n      fetchCall: fetch(apiCall, {\n        // Emulate XHR for Rails AJAX request checks\n        headers: {\n          \'X-Requested-With\': \'XMLHttpRequest\'\n        },\n        // fetch won’t send cookies in older browsers, unless you set the credentials init option.\n        // We set to `same-origin` which is default value in modern browsers.\n        // See https://github.com/whatwg/fetch/pull/585 for more information.\n        credentials: \'same-origin\'\n      })\n    };\n  });\n}\nif (gl.startup_graphql_calls && window.fetch) {\n  const headers = {"X-CSRF-Token":"g5+JXMNxnxMCcNbDa/OdRtEpP2B4YGMzbZptnQFxAIxVcHohIkHLh1N2SzDh+WNQIPq+SUv+TtVbi4SUe02hsw==","x-gitlab-feature-category":"projects"};\n  const url = `https://gitlab.com/api/graphql`\n\n  const opts = {\n    method: "POST",\n    headers: {\n      "Content-Type": "application/json",\n      ...headers,\n    }\n  };\n\n  gl.startup_graphql_calls = gl.startup_graphql_calls.map(call => ({\n    ...call,\n    fetchCall: fetch(url, {\n      ...opts,\n      credentials: \'same-origin\',\n      body: JSON.stringify(call)\n    })\n  }))\n}\n\n\n//]]>\n</script>\n<meta content="object" property="og:type">\n<meta content="GitLab" property="og:site_name">\n<meta content="Xavier / Tutoriels Ansible" property="og:title">\n<meta content="Découvrez les tutoriels ansible en français ici : https://youtu.be/kzmvwc2q_z0" property="og:description">\n<meta content="https://gitlab.com/uploads/-/sys ...
#     'merge_requests': {'url': 'https://gitlab.com/xavki/presentation-ansible-fr/-/merge_requests',
#      'html': '<!DOCTYPE html>\n<html class="" lang="en">\n<head prefix="og: http://ogp.me/ns#">\n<meta charset="utf-8">\n<link rel="preload" href="/assets/application_utilities-79bc2841975b0e515219eb7a828208ace79b8c07d0536e809746db7e22deeaab.css" as="style" type="text/css" nonce="ZgoZjD9g4Kujx4+ljBovCQ==">\n<link rel="preload" href="/assets/application-6eb5eaa5726150b8135a4fd09118cfd6b29f128586b7fa5019a04f1c740e9193.css" as="style" type="text/css" nonce="ZgoZjD9g4Kujx4+ljBovCQ==">\n<link rel="preload" href="/assets/highlight/themes/white-14ba9f209d5cc375d065606896b08ef3d4dc7be19e5b5800958b390d7ab2bd40.css" as="style" type="text/css" nonce="ZgoZjD9g4Kujx4+ljBovCQ==">\n<link crossorigin="" href="snowplow.trx.gitlab.net" rel="preconnect">\n\n<meta content="IE=edge" http-equiv="X-UA-Compatible">\n\n<meta content="object" property="og:type">\n<meta content="GitLab" property="og:site_name">\n<meta content="Merge requests · Xavier / Tutoriels Ansible" property="og:title">\n<meta content="Découvrez les tutoriels ansible en français ici : https://youtu.be/kzmvwc2q_z0" property="og:description">\n<meta content="https://gitlab.com/uploads/-/system/project/avatar/20975946/Ansible_logo-700x700.png" property="og:image">\n<meta content="64" property="og:image:width">\n<meta content="64" property="og:image:height">\n<meta content="https://gitlab.com/xavki/presentation-ansible-fr/-/merge_requests" property="og:url">\n<meta content="summary" property="twitter:card">\n<meta content="Merge requests · Xavier / Tutoriels Ansible" property="twitter:title">\n<meta content="Découvrez les tutoriels ansible en français ici : https://youtu.be/kzmvwc2q_z0" property="twitter:description">\n<meta content="https://gitlab.com/uploads/-/system/project/avatar/20975946/Ansible_logo-700x700.png" property="twitter:image">\n\n<title>Merge requests · Xavier / Tutoriels Ansible · GitLab</title>\n<meta content="Découvrez les tutoriels ansible en français ici : https://youtu.be/kzmvwc2q_z0" name="description">\n\n<link rel="shortcut icon" type="image/png" href="/assets/favicon-7901bd695fb93edb07975966062049829afb56cf11511236e61bcf425070e36e.png" id="favicon" data-original-href="/assets/favicon-7901bd695fb93edb07975966062049829afb56cf11511236e61bcf425070e36e.png" />\n<style>\n@keyframes blinking-dot{0%{opacity:1}25%{opacity:0.4}75%{opacity:0.4}100%{opacity:1}}@keyframes blinking-scroll-button{0%{opacity:0.2}50%{opacity:1}100%{opacity:0.2}}@keyframes gl-spinner-rotate{0%{transform:rotate(0)}100%{transform:rotate(360deg)}}body.ui-indigo{--gl-theme-accent: #6666c4}body.ui-indigo .navbar-gitlab{background-color:#292961}body.ui-indigo .navbar-gitlab .navbar-collapse{color:#d1d1f0}body.ui-indigo .navbar-gitlab .container-fluid .navbar-toggler{border-left:1px solid #6868b9;color:#d1d1f0}body.ui-indigo .navbar-gitlab .navbar-sub-nav>li>a:hover,body.ui-indigo .navbar-gitlab .navbar-sub-nav>li>a:focus,body.ui-indigo .navbar-gitlab .navbar-sub-nav>li>button:hover,body.ui-indigo .navbar-gitlab .navbar-sub-nav>li>button:focus,body.ui-indigo .navbar-gitlab .navbar-nav>li>a:hover,body.ui-indigo .navbar-gitlab .navbar-nav>li>a:focus,body.ui-indigo .navbar-gitlab .navbar-nav>li>button:hover,body.ui-indigo .navbar-gitlab .navbar-nav>li>button:focus{background-color:rgba(209,209,240,0.2)}body.ui-indigo .navbar-gitlab .navbar-sub-nav>li.active>a,body.ui-indigo .navbar-gitlab .navbar-sub-nav>li.active>button,body.ui-indigo .navbar-gitlab .navbar-sub-nav>li.dropdown.show>a,body.ui-indigo .navbar-gitlab .navbar-sub-nav>li.dropdown.show>button,body.ui-indigo .navbar-gitlab .navbar-nav>li.active>a,body.ui-indigo .navbar-gitlab .navbar-nav>li.active>button,body.ui-indigo .navbar-gitlab .navbar-nav>li.dropdown.show>a,body.ui-indigo .navbar-gitlab .navbar-nav>li.dropdown.show>button{color:#292961;background-color:#fff}body.ui-indigo .navbar-gitlab .navbar-sub-nav>li.line-separator,body.ui-indigo .navbar-gitlab .navbar-nav>li.line-separator{border-left:1px solid rgba(209,209,240,0.2)}body.ui-indigo ...
#   {'id': 8833156,
#    'description': '使用go写的v2ray gui客户端',
#    'name': 'v2rayXPlus',
#    'name_with_namespace': '夏叶随风 / v2rayXPlus',
#    'path': 'v2rayxplus',
#    'path_with_namespace': 'xiayesuifeng/v2rayxplus',
#    'created_at': '2018-10-12T14:57:45.642Z',
#    'default_branch': 'master',
#    'tag_list': [],
#    'topics': [],
#    'ssh_url_to_repo': 'git@gitlab.com:xiayesuifeng/v2rayxplus.git',
#    'http_url_to_repo': 'https://gitlab.com/xiayesuifeng/v2rayxplus.git',
#    'web_url': 'https://gitlab.com/xiayesuifeng/v2rayxplus',
#    'readme_url': 'https://gitlab.com/xiayesuifeng/v2rayxplus/-/blob/master/README.md',
#    'avatar_url': 'https://gitlab.com/uploads/-/system/project/avatar/8833156/V2ray.png',
#    'forks_count': 10,
#    'star_count': 43,
#    'last_activity_at': '2021-07-12T02:49:54.631Z',
#    'namespace': {'id': 2968552,
#     'name': '夏叶随风',
#     'path': 'xiayesuifeng',
#     'kind': 'user',
#     'full_path': 'xiayesuifeng',
#     'parent_id': None,
#     'avatar_url': 'https://secure.gravatar.com/avatar/03d2de1b6e56df11b1df119534579436?s=80&d=identicon',
#     'web_url': 'https://gitlab.com/xiayesuifeng'},
#    'access_time': 1647632131.5664377,
#    'groups': [],
#    'languages': {'Go': 100.0},
#    'issue_stats': {'counts': {'all': 3, 'closed': 3, 'opened': 0}},
#    'top_20_repository_contibutors': [{'name': 'xiayesuifeng',
#      'email': 'gdigrgg@gmail.com',
#      'commits': 251,
#      'additions': 0,
#      'deletions': 0}],
#    'from_page_stats_commits': '252',
#    'from_page_stats_branches': '1',
#    'from_page_stats_tags': '6',
#    'from_page_stats_files': '584 KB',
#    'from_page_stats_storage': '92.8 MB',
#    'html': {'main': {'url': 'https://gitlab.com/xiayesuifeng/v2rayxplus',
#      'html': '<!DOCTYPE html>\n<html class="" lang="en">\n<head prefix="og: http://ogp.me/ns#">\n<meta charset="utf-8">\n<link rel="preload" href="/assets/application_utilities-79bc2841975b0e515219eb7a828208ace79b8c07d0536e809746db7e22deeaab.css" as="style" type="text/css" nonce="ZgoZjD9g4Kujx4+ljBovCQ==">\n<link rel="preload" href="/assets/application-6eb5eaa5726150b8135a4fd09118cfd6b29f128586b7fa5019a04f1c740e9193.css" as="style" type="text/css" nonce="ZgoZjD9g4Kujx4+ljBovCQ==">\n<link rel="preload" href="/assets/highlight/themes/white-14ba9f209d5cc375d065606896b08ef3d4dc7be19e5b5800958b390d7ab2bd40.css" as="style" type="text/css" nonce="ZgoZjD9g4Kujx4+ljBovCQ==">\n<link crossorigin="" href="snowplow.trx.gitlab.net" rel="preconnect">\n\n<meta content="IE=edge" http-equiv="X-UA-Compatible">\n<script nonce="TNXjDYu14HeVqbNIC4fC8g==">\n//<![CDATA[\nvar gl = window.gl || {};\ngl.startup_calls = {"/xiayesuifeng/v2rayxplus/-/refs/master/logs_tree/?format=json\\u0026offset=0":{},"/xiayesuifeng/v2rayxplus/-/blob/master/README.md?format=json\\u0026viewer=rich":{}};\ngl.startup_graphql_calls = [{"query":"query pathLastCommit($projectPath: ID!, $path: String, $ref: String!) {\\n  project(fullPath: $projectPath) {\\n    __typename\\n    id\\n    repository {\\n      __typename\\n      tree(path: $path, ref: $ref) {\\n        __typename\\n        lastCommit {\\n          __typename\\n          id\\n          sha\\n          title\\n          titleHtml\\n          descriptionHtml\\n          message\\n          webPath\\n          authoredDate\\n          authorName\\n          authorGravatar\\n          author {\\n            __typename\\n            id\\n            name\\n            avatarUrl\\n            webPath\\n          }\\n          signatureHtml\\n          pipelines(ref: $ref, first: 1) {\\n            __typename\\n            edges {\\n              __typename\\n              node {\\n                __typename\\n                id\\n                detailedStatus {\\n                  __typename\\n                  id\\n                  detailsPath\\n                  icon\\n                  tooltip\\n                  text\\n                  group\\n                }\\n              }\\n            }\\n          }\\n        }\\n      }\\n    }\\n  }\\n}\\n","variables":{"projectPath":"xiayesuifeng/v2rayxplus","ref":"master","path":""}}];\n\nif (gl.startup_calls && window.fetch) {\n  Object.keys(gl.startup_calls).forEach(apiCall => {\n   gl.startup_calls[apiCall] = {\n      fetchCall: fetch(apiCall, {\n        // Emulate XHR for Rails AJAX request checks\n        headers: {\n          \'X-Requested-With\': \'XMLHttpRequest\'\n        },\n        // fetch won’t send cookies in older browsers, unless you set the credentials init option.\n        // We set to `same-origin` which is default value in modern browsers.\n        // See https://github.com/whatwg/fetch/pull/585 for more information.\n        credentials: \'same-origin\'\n      })\n    };\n  });\n}\nif (gl.startup_graphql_calls && window.fetch) {\n  const headers = {"X-CSRF-Token":"YfiiIW1aVeePHrtk18qqapa9GcTvuFvBmCRmtSZJNnVEeGM9wF+hLynrWZq0R1T6o3RBYWIQtOxWQ9VLX37e8g==","x-gitlab-feature-category":"projects"};\n  const url = `https://gitlab.com/api/graphql`\n\n  const opts = {\n    method: "POST",\n    headers: {\n      "Content-Type": "application/json",\n      ...headers,\n    }\n  };\n\n  gl.startup_graphql_calls = gl.startup_graphql_calls.map(call => ({\n    ...call,\n    fetchCall: fetch(url, {\n      ...opts,\n      credentials: \'same-origin\',\n      body: JSON.stringify(call)\n    })\n  }))\n}\n\n\n//]]>\n</script>\n<meta content="object" property="og:type">\n<meta content="GitLab" property="og:site_name">\n<meta content="夏叶随风 / v2rayXPlus" property="og:title">\n<meta content="使用go写的v2ray gui客户端" property="og:description">\n<meta content="https://gitlab.com/uploads/-/system/project/avatar/8833156/V2ray.png" property="og:image">\n<meta content="64" property ...
#     'merge_requests': {'url': 'https://gitlab.com/xiayesuifeng/v2rayxplus/-/merge_requests',
#      'html': '<!DOCTYPE html>\n<html class="" lang="en">\n<head prefix="og: http://ogp.me/ns#">\n<meta charset="utf-8">\n<link rel="preload" href="/assets/application_utilities-79bc2841975b0e515219eb7a828208ace79b8c07d0536e809746db7e22deeaab.css" as="style" type="text/css" nonce="ZgoZjD9g4Kujx4+ljBovCQ==">\n<link rel="preload" href="/assets/application-6eb5eaa5726150b8135a4fd09118cfd6b29f128586b7fa5019a04f1c740e9193.css" as="style" type="text/css" nonce="ZgoZjD9g4Kujx4+ljBovCQ==">\n<link rel="preload" href="/assets/highlight/themes/white-14ba9f209d5cc375d065606896b08ef3d4dc7be19e5b5800958b390d7ab2bd40.css" as="style" type="text/css" nonce="ZgoZjD9g4Kujx4+ljBovCQ==">\n<link crossorigin="" href="snowplow.trx.gitlab.net" rel="preconnect">\n\n<meta content="IE=edge" http-equiv="X-UA-Compatible">\n\n<meta content="object" property="og:type">\n<meta content="GitLab" property="og:site_name">\n<meta content="Merge requests · 夏叶随风 / v2rayXPlus" property="og:title">\n<meta content="使用go写的v2ray gui客户端" property="og:description">\n<meta content="https://gitlab.com/uploads/-/system/project/avatar/8833156/V2ray.png" property="og:image">\n<meta content="64" property="og:image:width">\n<meta content="64" property="og:image:height">\n<meta content="https://gitlab.com/xiayesuifeng/v2rayxplus/-/merge_requests" property="og:url">\n<meta content="summary" property="twitter:card">\n<meta content="Merge requests · 夏叶随风 / v2rayXPlus" property="twitter:title">\n<meta content="使用go写的v2ray gui客户端" property="twitter:description">\n<meta content="https://gitlab.com/uploads/-/system/project/avatar/8833156/V2ray.png" property="twitter:image">\n\n<title>Merge requests · 夏叶随风 / v2rayXPlus · GitLab</title>\n<meta content="使用go写的v2ray gui客户端" name="description">\n\n<link rel="shortcut icon" type="image/png" href="/assets/favicon-7901bd695fb93edb07975966062049829afb56cf11511236e61bcf425070e36e.png" id="favicon" data-original-href="/assets/favicon-7901bd695fb93edb07975966062049829afb56cf11511236e61bcf425070e36e.png" />\n<style>\n@keyframes blinking-dot{0%{opacity:1}25%{opacity:0.4}75%{opacity:0.4}100%{opacity:1}}@keyframes blinking-scroll-button{0%{opacity:0.2}50%{opacity:1}100%{opacity:0.2}}@keyframes gl-spinner-rotate{0%{transform:rotate(0)}100%{transform:rotate(360deg)}}body.ui-indigo{--gl-theme-accent: #6666c4}body.ui-indigo .navbar-gitlab{background-color:#292961}body.ui-indigo .navbar-gitlab .navbar-collapse{color:#d1d1f0}body.ui-indigo .navbar-gitlab .container-fluid .navbar-toggler{border-left:1px solid #6868b9;color:#d1d1f0}body.ui-indigo .navbar-gitlab .navbar-sub-nav>li>a:hover,body.ui-indigo .navbar-gitlab .navbar-sub-nav>li>a:focus,body.ui-indigo .navbar-gitlab .navbar-sub-nav>li>button:hover,body.ui-indigo .navbar-gitlab .navbar-sub-nav>li>button:focus,body.ui-indigo .navbar-gitlab .navbar-nav>li>a:hover,body.ui-indigo .navbar-gitlab .navbar-nav>li>a:focus,body.ui-indigo .navbar-gitlab .navbar-nav>li>button:hover,body.ui-indigo .navbar-gitlab .navbar-nav>li>button:focus{background-color:rgba(209,209,240,0.2)}body.ui-indigo .navbar-gitlab .navbar-sub-nav>li.active>a,body.ui-indigo .navbar-gitlab .navbar-sub-nav>li.active>button,body.ui-indigo .navbar-gitlab .navbar-sub-nav>li.dropdown.show>a,body.ui-indigo .navbar-gitlab .navbar-sub-nav>li.dropdown.show>button,body.ui-indigo .navbar-gitlab .navbar-nav>li.active>a,body.ui-indigo .navbar-gitlab .navbar-nav>li.active>button,body.ui-indigo .navbar-gitlab .navbar-nav>li.dropdown.show>a,body.ui-indigo .navbar-gitlab .navbar-nav>li.dropdown.show>button{color:#292961;background-color:#fff}body.ui-indigo .navbar-gitlab .navbar-sub-nav>li.line-separator,body.ui-indigo .navbar-gitlab .navbar-nav>li.line-separator{border-left:1px solid rgba(209,209,240,0.2)}body.ui-indigo .navbar-gitlab .navbar-sub-nav{color:#d1d1f0}body.ui-indigo .navbar-gitlab .nav>li{color:#d1d1f0}body.ui-indigo .navbar-gitlab .nav>li.header-search-new{color:#303030}body.ui-indigo .navbar-gitlab .nav>li>a .notification-dot{border:2px solid #2 ...
#   {'id': 22804922,
#    'description': 'Nekogram is an open-source third-party Telegram client with not many but useful mods.\r\nhttps://nekogram.app',
#    'name': 'Nekogram',
#    'name_with_namespace': 'Nekogram / Nekogram',
#    'path': 'Nekogram',
#    'path_with_namespace': 'Nekogram/Nekogram',
#    'created_at': '2020-12-01T07:11:14.952Z',
#    'default_branch': 'main',
#    'tag_list': ['nekogram', 'telegram'],
#    'topics': ['nekogram', 'telegram'],
#    'ssh_url_to_repo': 'git@gitlab.com:Nekogram/Nekogram.git',
#    'http_url_to_repo': 'https://gitlab.com/Nekogram/Nekogram.git',
#    'web_url': 'https://gitlab.com/Nekogram/Nekogram',
#    'readme_url': 'https://gitlab.com/Nekogram/Nekogram/-/blob/main/README.md',
#    'avatar_url': 'https://gitlab.com/uploads/-/system/project/avatar/22804922/ic_launcher-web.png',
#    'forks_count': 13,
#    'star_count': 43,
#    'last_activity_at': '2022-03-16T14:06:42.280Z',
#    'namespace': {'id': 10273976,
#     'name': 'Nekogram',
#     'path': 'Nekogram',
#     'kind': 'group',
#     'full_path': 'Nekogram',
#     'parent_id': None,
#     'avatar_url': '/uploads/-/system/group/avatar/10273976/ic_launcher-web.png',
#     'web_url': 'https://gitlab.com/groups/Nekogram'},
#    'access_time': 1647632135.632341,
#    'groups': [{'id': 10273976,
#      'web_url': 'https://gitlab.com/groups/Nekogram',
#      'name': 'Nekogram',
#      'avatar_url': 'https://gitlab.com/uploads/-/system/group/avatar/10273976/ic_launcher-web.png',
#      'full_name': 'Nekogram',
#      'full_path': 'Nekogram',
#      'project_id': 22804922}],
#    'languages': {'C++': 35.33,
#     'Java': 35.04,
#     'C': 23.48,
#     'Assembly': 1.97,
#     'Perl': 1.75},
#    'issue_stats': {'counts': {'all': 36, 'closed': 31, 'opened': 5}},
#    'top_20_repository_contibutors': [{'name': 'NekoInverter',
#      'email': '42698724+NekoInverter@users.noreply.github.com',
#      'commits': 328,
#      'additions': 0,
#      'deletions': 0},
#     {'name': 'DrKLO',
#      'email': 'drklo.2kb@gmail.com',
#      'commits': 287,
#      'additions': 0,
#      'deletions': 0},
#     {'name': 'tehcneko',
#      'email': '7741672-NekoInverter@users.noreply.gitlab.com',
#      'commits': 260,
#      'additions': 0,
#      'deletions': 0},
#     {'name': 'NekoInverter',
#      'email': 'chsqwyx@gmail.com',
#      'commits': 164,
#      'additions': 0,
#      'deletions': 0},
#     {'name': 'tehcneko',
#      'email': '7764726+tehcneko@users.noreply.github.com',
#      'commits': 145,
#      'additions': 0,
#      'deletions': 0},
#     {'name': 'Riko Sakurauchi',
#      'email': 'lijiahao99131@gmail.com',
#      'commits': 130,
#      'additions': 0,
#      'deletions': 0},
#     {'name': 'DrKLO',
#      'email': 'drklo.dev@gmail.com',
#      'commits': 75,
#      'additions': 0,
#      'deletions': 0},
#     {'name': 'xaxtix',
#      'email': 'xardas3200@gmail.com',
#      'commits': 24,
#      'additions': 0,
#      'deletions': 0},
#     {'name': 'AlexandrKozlovskiy',
#      'email': 'k.sasha1994@gmail.com',
#      'commits': 10,
#      'additions': 0,
#      'deletions': 0},
#     {'name': '23rd',
#      'email': '23rd@vivaldi.net',
#      'commits': 6,
#      'additions': 0,
#      'deletions': 0},
#     {'name': 'Dan Albert',
#      'email': 'danalbert@google.com',
#      'commits': 6,
#      'additions': 0,
#      'deletions': 0},
#     {'name': 'DrKLO',
#      'email': 'DrKLO@iMac-Nikolay.local',
#      'commits': 6,
#      'additions': 0,
#      'deletions': 0},
#     {'name': 'Alisson Lauffer',
#      'email': 'alissonvitortc@gmail.com',
#      'commits': 4,
#      'additions': 0,
#      'deletions': 0},
#     {'name': 'YTKAB0BP',
#      'email': 'utkabobr@utkacraft.ru',
#      'commits': 2,
#      'additions': 0,
#      'deletions': 0},
#     {'name': 'LI JIAHAO',
#      'email': 'jh.li@maimemo.com',
#      'commits': 2,
#      'additions': 0,
#      'deletions': 0},
#     {'name': 'Dacainiao',
#      'email': 'chijiabao@gmail.com',
#      'commits': 2,
#      'additions': 0,
#      'deletions': 0},
#     {'name': 'Nick C',
#      'email': 'pokemonnekitgod@gmail.com',
#      'commits': 1,
#      'additions': 0,
#      'deletions': 0},
#     {'name': 'ATrain',
#      'email': 'atrain@atrain.ca',
#      'commits': 1,
#      'additions': 0,
#      'deletions': 0},
#     {'name': 'Nick C',
#      'email': 'ctwoon@suicide.today',
#      'commits': 1,
#      'additions': 0,
#      'deletions': 0},
#     {'name': 'Grishka',
#      'email': 'grishka93@gmail.com',
#      'commits': 1,
#      'additions': 0,
#      'deletions': 0}],
#    'from_page_stats_commits': '1,601',
#    'from_page_stats_branches': '2',
#    'from_page_stats_tags': '9',
#    'from_page_stats_files': '27.9 MB',
#    'from_page_stats_storage': '50.7 MB',
#    'num_merge_requests_opened': 1,
#    'num_merge_requests_merged': 46,
#    'num_merge_requests_closed': 30,
#    'num_merge_requests_all': 77,
#    'html': {'main': {'url': 'https://gitlab.com/Nekogram/Nekogram',
#      'html': '<!DOCTYPE html>\n<html class="" lang="en">\n<head prefix="og: http://ogp.me/ns#">\n<meta charset="utf-8">\n<link rel="preload" href="/assets/application_utilities-79bc2841975b0e515219eb7a828208ace79b8c07d0536e809746db7e22deeaab.css" as="style" type="text/css" nonce="ZgoZjD9g4Kujx4+ljBovCQ==">\n<link rel="preload" href="/assets/application-6eb5eaa5726150b8135a4fd09118cfd6b29f128586b7fa5019a04f1c740e9193.css" as="style" type="text/css" nonce="ZgoZjD9g4Kujx4+ljBovCQ==">\n<link rel="preload" href="/assets/highlight/themes/white-14ba9f209d5cc375d065606896b08ef3d4dc7be19e5b5800958b390d7ab2bd40.css" as="style" type="text/css" nonce="ZgoZjD9g4Kujx4+ljBovCQ==">\n<link crossorigin="" href="snowplow.trx.gitlab.net" rel="preconnect">\n\n<meta content="IE=edge" http-equiv="X-UA-Compatible">\n<script nonce="lSOuJIVGahU6du/NDdTl2g==">\n//<![CDATA[\nvar gl = window.gl || {};\ngl.startup_calls = {"/Nekogram/Nekogram/-/refs/main/logs_tree/?format=json\\u0026offset=0":{},"/Nekogram/Nekogram/-/blob/main/README.md?format=json\\u0026viewer=rich":{}};\ngl.startup_graphql_calls = [{"query":"query pathLastCommit($projectPath: ID!, $path: String, $ref: String!) {\\n  project(fullPath: $projectPath) {\\n    __typename\\n    id\\n    repository {\\n      __typename\\n      tree(path: $path, ref: $ref) {\\n        __typename\\n        lastCommit {\\n          __typename\\n          id\\n          sha\\n          title\\n          titleHtml\\n          descriptionHtml\\n          message\\n          webPath\\n          authoredDate\\n          authorName\\n          authorGravatar\\n          author {\\n            __typename\\n            id\\n            name\\n            avatarUrl\\n            webPath\\n          }\\n          signatureHtml\\n          pipelines(ref: $ref, first: 1) {\\n            __typename\\n            edges {\\n              __typename\\n              node {\\n                __typename\\n                id\\n                detailedStatus {\\n                  __typename\\n                  id\\n                  detailsPath\\n                  icon\\n                  tooltip\\n                  text\\n                  group\\n                }\\n              }\\n            }\\n          }\\n        }\\n      }\\n    }\\n  }\\n}\\n","variables":{"projectPath":"Nekogram/Nekogram","ref":"main","path":""}}];\n\nif (gl.startup_calls && window.fetch) {\n  Object.keys(gl.startup_calls).forEach(apiCall => {\n   gl.startup_calls[apiCall] = {\n      fetchCall: fetch(apiCall, {\n        // Emulate XHR for Rails AJAX request checks\n        headers: {\n          \'X-Requested-With\': \'XMLHttpRequest\'\n        },\n        // fetch won’t send cookies in older browsers, unless you set the credentials init option.\n        // We set to `same-origin` which is default value in modern browsers.\n        // See https://github.com/whatwg/fetch/pull/585 for more information.\n        credentials: \'same-origin\'\n      })\n    };\n  });\n}\nif (gl.startup_graphql_calls && window.fetch) {\n  const headers = {"X-CSRF-Token":"YsV+EtJ0dAfaAWE0SVResAwxgwax9FbJi4sdzLbkaWC6NwL815euVbg3EgiINs1EJ6GOrBDuJ37hhE/xFT3iCA==","x-gitlab-feature-category":"projects"};\n  const url = `https://gitlab.com/api/graphql`\n\n  const opts = {\n    method: "POST",\n    headers: {\n      "Content-Type": "application/json",\n      ...headers,\n    }\n  };\n\n  gl.startup_graphql_calls = gl.startup_graphql_calls.map(call => ({\n    ...call,\n    fetchCall: fetch(url, {\n      ...opts,\n      credentials: \'same-origin\',\n      body: JSON.stringify(call)\n    })\n  }))\n}\n\n\n//]]>\n</script>\n<meta content="object" property="og:type">\n<meta content="GitLab" property="og:site_name">\n<meta content="Nekogram / Nekogram" property="og:title">\n<meta content="Nekogram is an open-source third-party Telegram client with not many but useful mods. https://nekogram.app" property="og:description">\n<meta content="https://gitlab.com/uploads/-/system/project/avatar/22 ...
#     'merge_requests': {'url': 'https://gitlab.com/Nekogram/Nekogram/-/merge_requests',
#      'html': '<!DOCTYPE html>\n<html class="" lang="en">\n<head prefix="og: http://ogp.me/ns#">\n<meta charset="utf-8">\n<link rel="preload" href="/assets/application_utilities-79bc2841975b0e515219eb7a828208ace79b8c07d0536e809746db7e22deeaab.css" as="style" type="text/css" nonce="ZgoZjD9g4Kujx4+ljBovCQ==">\n<link rel="preload" href="/assets/application-6eb5eaa5726150b8135a4fd09118cfd6b29f128586b7fa5019a04f1c740e9193.css" as="style" type="text/css" nonce="ZgoZjD9g4Kujx4+ljBovCQ==">\n<link rel="preload" href="/assets/highlight/themes/white-14ba9f209d5cc375d065606896b08ef3d4dc7be19e5b5800958b390d7ab2bd40.css" as="style" type="text/css" nonce="ZgoZjD9g4Kujx4+ljBovCQ==">\n<link crossorigin="" href="snowplow.trx.gitlab.net" rel="preconnect">\n\n<meta content="IE=edge" http-equiv="X-UA-Compatible">\n\n<meta content="object" property="og:type">\n<meta content="GitLab" property="og:site_name">\n<meta content="Merge requests · Nekogram / Nekogram" property="og:title">\n<meta content="Nekogram is an open-source third-party Telegram client with not many but useful mods. https://nekogram.app" property="og:description">\n<meta content="https://gitlab.com/uploads/-/system/project/avatar/22804922/ic_launcher-web.png" property="og:image">\n<meta content="64" property="og:image:width">\n<meta content="64" property="og:image:height">\n<meta content="https://gitlab.com/Nekogram/Nekogram/-/merge_requests" property="og:url">\n<meta content="summary" property="twitter:card">\n<meta content="Merge requests · Nekogram / Nekogram" property="twitter:title">\n<meta content="Nekogram is an open-source third-party Telegram client with not many but useful mods. https://nekogram.app" property="twitter:description">\n<meta content="https://gitlab.com/uploads/-/system/project/avatar/22804922/ic_launcher-web.png" property="twitter:image">\n\n<title>Merge requests · Nekogram / Nekogram · GitLab</title>\n<meta content="Nekogram is an open-source third-party Telegram client with not many but useful mods. https://nekogram.app" name="description">\n\n<link rel="shortcut icon" type="image/png" href="/assets/favicon-7901bd695fb93edb07975966062049829afb56cf11511236e61bcf425070e36e.png" id="favicon" data-original-href="/assets/favicon-7901bd695fb93edb07975966062049829afb56cf11511236e61bcf425070e36e.png" />\n<style>\n@keyframes blinking-dot{0%{opacity:1}25%{opacity:0.4}75%{opacity:0.4}100%{opacity:1}}@keyframes blinking-scroll-button{0%{opacity:0.2}50%{opacity:1}100%{opacity:0.2}}@keyframes gl-spinner-rotate{0%{transform:rotate(0)}100%{transform:rotate(360deg)}}body.ui-indigo{--gl-theme-accent: #6666c4}body.ui-indigo .navbar-gitlab{background-color:#292961}body.ui-indigo .navbar-gitlab .navbar-collapse{color:#d1d1f0}body.ui-indigo .navbar-gitlab .container-fluid .navbar-toggler{border-left:1px solid #6868b9;color:#d1d1f0}body.ui-indigo .navbar-gitlab .navbar-sub-nav>li>a:hover,body.ui-indigo .navbar-gitlab .navbar-sub-nav>li>a:focus,body.ui-indigo .navbar-gitlab .navbar-sub-nav>li>button:hover,body.ui-indigo .navbar-gitlab .navbar-sub-nav>li>button:focus,body.ui-indigo .navbar-gitlab .navbar-nav>li>a:hover,body.ui-indigo .navbar-gitlab .navbar-nav>li>a:focus,body.ui-indigo .navbar-gitlab .navbar-nav>li>button:hover,body.ui-indigo .navbar-gitlab .navbar-nav>li>button:focus{background-color:rgba(209,209,240,0.2)}body.ui-indigo .navbar-gitlab .navbar-sub-nav>li.active>a,body.ui-indigo .navbar-gitlab .navbar-sub-nav>li.active>button,body.ui-indigo .navbar-gitlab .navbar-sub-nav>li.dropdown.show>a,body.ui-indigo .navbar-gitlab .navbar-sub-nav>li.dropdown.show>button,body.ui-indigo .navbar-gitlab .navbar-nav>li.active>a,body.ui-indigo .navbar-gitlab .navbar-nav>li.active>button,body.ui-indigo .navbar-gitlab .navbar-nav>li.dropdown.show>a,body.ui-indigo .navbar-gitlab .navbar-nav>li.dropdown.show>button{color:#292961;background-color:#fff}body.ui-indigo .navbar-gitlab .navbar-sub-nav>li.line-separator,body.ui-indigo .navbar-gitlab .navbar-nav>li.line-separator{border-left:1px s ...
#   {'id': 7292712,
#    'description': 'RosarioSIS Student Information System for school management',
#    'name': 'rosariosis',
#    'name_with_namespace': 'François Jacquet / rosariosis',
#    'path': 'rosariosis',
#    'path_with_namespace': 'francoisjacquet/rosariosis',
#    'created_at': '2018-06-29T12:41:30.177Z',
#    'default_branch': 'mobile',
#    'tag_list': ['attendance',
#     'education',
#     'erp',
#     'gradebook',
#     'management',
#     'school',
#     'student',
#     'teacher',
#     'timetable'],
#    'topics': ['attendance',
#     'education',
#     'erp',
#     'gradebook',
#     'management',
#     'school',
#     'student',
#     'teacher',
#     'timetable'],
#    'ssh_url_to_repo': 'git@gitlab.com:francoisjacquet/rosariosis.git',
#    'http_url_to_repo': 'https://gitlab.com/francoisjacquet/rosariosis.git',
#    'web_url': 'https://gitlab.com/francoisjacquet/rosariosis',
#    'readme_url': 'https://gitlab.com/francoisjacquet/rosariosis/-/blob/mobile/README.md',
#    'avatar_url': 'https://gitlab.com/uploads/-/system/project/avatar/7292712/graduation-hat_white_bg_148_round_avatar.png',
#    'forks_count': 31,
#    'star_count': 43,
#    'last_activity_at': '2022-03-17T19:19:47.278Z',
#    'namespace': {'id': 3120162,
#     'name': 'François Jacquet',
#     'path': 'francoisjacquet',
#     'kind': 'user',
#     'full_path': 'francoisjacquet',
#     'parent_id': None,
#     'avatar_url': '/uploads/-/system/user/avatar/2496870/avatar.png',
#     'web_url': 'https://gitlab.com/francoisjacquet'},
#    'access_time': 1647632130.7377322,
#    'groups': [],
#    'languages': {'PHP': 68.64,
#     'JavaScript': 24.63,
#     'CSS': 3.84,
#     'PLpgSQL': 2.72,
#     'HTML': 0.17},
#    'issue_stats': {'counts': {'all': 318, 'closed': 300, 'opened': 18}},
#    'top_20_repository_contibutors': [{'name': 'François Jacquet',
#      'email': 'francoisjacquet@users.noreply.github.com',
#      'commits': 1997,
#      'additions': 0,
#      'deletions': 0},
#     {'name': 'François Jacquet',
#      'email': 'info@rosariosis.org',
#      'commits': 2,
#      'additions': 0,
#      'deletions': 0},
#     {'name': 'Dzung Do',
#      'email': 'ddo@redhat.com',
#      'commits': 1,
#      'additions': 0,
#      'deletions': 0}],
#    'from_page_stats_commits': '5,386',
#    'from_page_stats_branches': '25',
#    'from_page_stats_tags': '362',
#    'from_page_stats_files': '2.8 MB',
#    'from_page_stats_storage': '15.4 MB',
#    'from_page_stats_releases': '356',
#    'num_merge_requests_opened': 0,
#    'num_merge_requests_merged': 8,
#    'num_merge_requests_closed': 7,
#    'num_merge_requests_all': 15,
#    'html': {'main': {'url': 'https://gitlab.com/francoisjacquet/rosariosis',
#      'html': '<!DOCTYPE html>\n<html class="" lang="en">\n<head prefix="og: http://ogp.me/ns#">\n<meta charset="utf-8">\n<link rel="preload" href="/assets/application_utilities-79bc2841975b0e515219eb7a828208ace79b8c07d0536e809746db7e22deeaab.css" as="style" type="text/css" nonce="ZgoZjD9g4Kujx4+ljBovCQ==">\n<link rel="preload" href="/assets/application-6eb5eaa5726150b8135a4fd09118cfd6b29f128586b7fa5019a04f1c740e9193.css" as="style" type="text/css" nonce="ZgoZjD9g4Kujx4+ljBovCQ==">\n<link rel="preload" href="/assets/highlight/themes/white-14ba9f209d5cc375d065606896b08ef3d4dc7be19e5b5800958b390d7ab2bd40.css" as="style" type="text/css" nonce="ZgoZjD9g4Kujx4+ljBovCQ==">\n<link crossorigin="" href="snowplow.trx.gitlab.net" rel="preconnect">\n\n<meta content="IE=edge" http-equiv="X-UA-Compatible">\n<script nonce="iZpZOCkKWasMqfTDFLj7yw==">\n//<![CDATA[\nvar gl = window.gl || {};\ngl.startup_calls = {"/francoisjacquet/rosariosis/-/refs/mobile/logs_tree/?format=json\\u0026offset=0":{},"/francoisjacquet/rosariosis/-/blob/mobile/README.md?format=json\\u0026viewer=rich":{}};\ngl.startup_graphql_calls = [{"query":"query pathLastCommit($projectPath: ID!, $path: String, $ref: String!) {\\n  project(fullPath: $projectPath) {\\n    __typename\\n    id\\n    repository {\\n      __typename\\n      tree(path: $path, ref: $ref) {\\n        __typename\\n        lastCommit {\\n          __typename\\n          id\\n          sha\\n          title\\n          titleHtml\\n          descriptionHtml\\n          message\\n          webPath\\n          authoredDate\\n          authorName\\n          authorGravatar\\n          author {\\n            __typename\\n            id\\n            name\\n            avatarUrl\\n            webPath\\n          }\\n          signatureHtml\\n          pipelines(ref: $ref, first: 1) {\\n            __typename\\n            edges {\\n              __typename\\n              node {\\n                __typename\\n                id\\n                detailedStatus {\\n                  __typename\\n                  id\\n                  detailsPath\\n                  icon\\n                  tooltip\\n                  text\\n                  group\\n                }\\n              }\\n            }\\n          }\\n        }\\n      }\\n    }\\n  }\\n}\\n","variables":{"projectPath":"francoisjacquet/rosariosis","ref":"mobile","path":""}}];\n\nif (gl.startup_calls && window.fetch) {\n  Object.keys(gl.startup_calls).forEach(apiCall => {\n   gl.startup_calls[apiCall] = {\n      fetchCall: fetch(apiCall, {\n        // Emulate XHR for Rails AJAX request checks\n        headers: {\n          \'X-Requested-With\': \'XMLHttpRequest\'\n        },\n        // fetch won’t send cookies in older browsers, unless you set the credentials init option.\n        // We set to `same-origin` which is default value in modern browsers.\n        // See https://github.com/whatwg/fetch/pull/585 for more information.\n        credentials: \'same-origin\'\n      })\n    };\n  });\n}\nif (gl.startup_graphql_calls && window.fetch) {\n  const headers = {"X-CSRF-Token":"kQGTPe4n9aX4I5yZG0qz5u3n0INldxjIOX0VRRf6fr31hNMiwaayJBaflyPbUiZFlP2woGfsihEJsqQYTXTy+g==","x-gitlab-feature-category":"projects"};\n  const url = `https://gitlab.com/api/graphql`\n\n  const opts = {\n    method: "POST",\n    headers: {\n      "Content-Type": "application/json",\n      ...headers,\n    }\n  };\n\n  gl.startup_graphql_calls = gl.startup_graphql_calls.map(call => ({\n    ...call,\n    fetchCall: fetch(url, {\n      ...opts,\n      credentials: \'same-origin\',\n      body: JSON.stringify(call)\n    })\n  }))\n}\n\n\n//]]>\n</script>\n<meta content="object" property="og:type">\n<meta content="GitLab" property="og:site_name">\n<meta content="François Jacquet / rosariosis" property="og:title">\n<meta content="RosarioSIS Student Information System for school management" property="og:description">\n<meta content="https://gitlab.com/uploads/-/system/project/avatar/729271 ...
#     'merge_requests': {'url': 'https://gitlab.com/francoisjacquet/rosariosis/-/merge_requests',
#      'html': '<!DOCTYPE html>\n<html class="" lang="en">\n<head prefix="og: http://ogp.me/ns#">\n<meta charset="utf-8">\n<link rel="preload" href="/assets/application_utilities-79bc2841975b0e515219eb7a828208ace79b8c07d0536e809746db7e22deeaab.css" as="style" type="text/css" nonce="ZgoZjD9g4Kujx4+ljBovCQ==">\n<link rel="preload" href="/assets/application-6eb5eaa5726150b8135a4fd09118cfd6b29f128586b7fa5019a04f1c740e9193.css" as="style" type="text/css" nonce="ZgoZjD9g4Kujx4+ljBovCQ==">\n<link rel="preload" href="/assets/highlight/themes/white-14ba9f209d5cc375d065606896b08ef3d4dc7be19e5b5800958b390d7ab2bd40.css" as="style" type="text/css" nonce="ZgoZjD9g4Kujx4+ljBovCQ==">\n<link crossorigin="" href="snowplow.trx.gitlab.net" rel="preconnect">\n\n<meta content="IE=edge" http-equiv="X-UA-Compatible">\n\n<meta content="object" property="og:type">\n<meta content="GitLab" property="og:site_name">\n<meta content="Merge requests · François Jacquet / rosariosis" property="og:title">\n<meta content="RosarioSIS Student Information System for school management" property="og:description">\n<meta content="https://gitlab.com/uploads/-/system/project/avatar/7292712/graduation-hat_white_bg_148_round_avatar.png" property="og:image">\n<meta content="64" property="og:image:width">\n<meta content="64" property="og:image:height">\n<meta content="https://gitlab.com/francoisjacquet/rosariosis/-/merge_requests" property="og:url">\n<meta content="summary" property="twitter:card">\n<meta content="Merge requests · François Jacquet / rosariosis" property="twitter:title">\n<meta content="RosarioSIS Student Information System for school management" property="twitter:description">\n<meta content="https://gitlab.com/uploads/-/system/project/avatar/7292712/graduation-hat_white_bg_148_round_avatar.png" property="twitter:image">\n\n<title>Merge requests · François Jacquet / rosariosis · GitLab</title>\n<meta content="RosarioSIS Student Information System for school management" name="description">\n\n<link rel="shortcut icon" type="image/png" href="/assets/favicon-7901bd695fb93edb07975966062049829afb56cf11511236e61bcf425070e36e.png" id="favicon" data-original-href="/assets/favicon-7901bd695fb93edb07975966062049829afb56cf11511236e61bcf425070e36e.png" />\n<style>\n@keyframes blinking-dot{0%{opacity:1}25%{opacity:0.4}75%{opacity:0.4}100%{opacity:1}}@keyframes blinking-scroll-button{0%{opacity:0.2}50%{opacity:1}100%{opacity:0.2}}@keyframes gl-spinner-rotate{0%{transform:rotate(0)}100%{transform:rotate(360deg)}}body.ui-indigo{--gl-theme-accent: #6666c4}body.ui-indigo .navbar-gitlab{background-color:#292961}body.ui-indigo .navbar-gitlab .navbar-collapse{color:#d1d1f0}body.ui-indigo .navbar-gitlab .container-fluid .navbar-toggler{border-left:1px solid #6868b9;color:#d1d1f0}body.ui-indigo .navbar-gitlab .navbar-sub-nav>li>a:hover,body.ui-indigo .navbar-gitlab .navbar-sub-nav>li>a:focus,body.ui-indigo .navbar-gitlab .navbar-sub-nav>li>button:hover,body.ui-indigo .navbar-gitlab .navbar-sub-nav>li>button:focus,body.ui-indigo .navbar-gitlab .navbar-nav>li>a:hover,body.ui-indigo .navbar-gitlab .navbar-nav>li>a:focus,body.ui-indigo .navbar-gitlab .navbar-nav>li>button:hover,body.ui-indigo .navbar-gitlab .navbar-nav>li>button:focus{background-color:rgba(209,209,240,0.2)}body.ui-indigo .navbar-gitlab .navbar-sub-nav>li.active>a,body.ui-indigo .navbar-gitlab .navbar-sub-nav>li.active>button,body.ui-indigo .navbar-gitlab .navbar-sub-nav>li.dropdown.show>a,body.ui-indigo .navbar-gitlab .navbar-sub-nav>li.dropdown.show>button,body.ui-indigo .navbar-gitlab .navbar-nav>li.active>a,body.ui-indigo .navbar-gitlab .navbar-nav>li.active>button,body.ui-indigo .navbar-gitlab .navbar-nav>li.dropdown.show>a,body.ui-indigo .navbar-gitlab .navbar-nav>li.dropdown.show>button{color:#292961;background-color:#fff}body.ui-indigo .navbar-gitlab .navbar-sub-nav>li.line-separator,body.ui-indigo .navbar-gitlab .navbar-nav>li.line-separator{border-left:1px solid rgba(209,209,240,0.2)}body.ui-indigo .navbar-gitl ...
#   {'id': 7777404,
#    'description': 'Example VuePress site using GitLab Pages: https://pages.gitlab.io/vuepress',
#    'name': 'vuepress',
#    'name_with_namespace': 'GitLab Pages examples / vuepress',
#    'path': 'vuepress',
#    'path_with_namespace': 'pages/vuepress',
#    'created_at': '2018-08-06T10:03:20.305Z',
#    'default_branch': 'master',
#    'tag_list': [],
#    'topics': [],
#    'ssh_url_to_repo': 'git@gitlab.com:pages/vuepress.git',
#    'http_url_to_repo': 'https://gitlab.com/pages/vuepress.git',
#    'web_url': 'https://gitlab.com/pages/vuepress',
#    'readme_url': 'https://gitlab.com/pages/vuepress/-/blob/master/README.md',
#    'avatar_url': 'https://gitlab.com/uploads/-/system/project/avatar/7777404/vuepress.png',
#    'forks_count': 173,
#    'star_count': 43,
#    'last_activity_at': '2021-09-23T14:49:15.259Z',
#    'namespace': {'id': 500013,
#     'name': 'GitLab Pages examples',
#     'path': 'pages',
#     'kind': 'group',
#     'full_path': 'pages',
#     'parent_id': None,
#     'avatar_url': '/uploads/-/system/group/avatar/500013/pages_group_avatar.png',
#     'web_url': 'https://gitlab.com/groups/pages'},
#    'access_time': 1647632133.3127935,
#    'groups': [{'id': 500013,
#      'web_url': 'https://gitlab.com/groups/pages',
#      'name': 'GitLab Pages examples',
#      'avatar_url': 'https://gitlab.com/uploads/-/system/group/avatar/500013/pages_group_avatar.png',
#      'full_name': 'GitLab Pages examples',
#      'full_path': 'pages',
#      'project_id': 7777404}],
#    'languages': {},
#    'issue_stats': {'counts': {'all': 2, 'closed': 1, 'opened': 1}},
#    'top_20_repository_contibutors': [{'name': 'Sam Beckham',
#      'email': 'sbeckham@gitlab.com',
#      'commits': 7,
#      'additions': 0,
#      'deletions': 0},
#     {'name': 'Achilleas Pipinellis',
#      'email': 'axil@gitlab.com',
#      'commits': 4,
#      'additions': 0,
#      'deletions': 0},
#     {'name': 'chaozding',
#      'email': '3261391-chaozding@users.noreply.gitlab.com',
#      'commits': 1,
#      'additions': 0,
#      'deletions': 0}],
#    'from_page_stats_commits': '15',
#    'from_page_stats_branches': '1',
#    'from_page_stats_tags': '0',
#    'from_page_stats_files': '12.3 MB',
#    'from_page_stats_storage': '13.6 MB',
#    'num_merge_requests_opened': 1,
#    'num_merge_requests_merged': 2,
#    'num_merge_requests_closed': 4,
#    'num_merge_requests_all': 7,
#    'html': {'main': {'url': 'https://gitlab.com/pages/vuepress',
#      'html': '<!DOCTYPE html>\n<html class="" lang="en">\n<head prefix="og: http://ogp.me/ns#">\n<meta charset="utf-8">\n<link rel="preload" href="/assets/application_utilities-79bc2841975b0e515219eb7a828208ace79b8c07d0536e809746db7e22deeaab.css" as="style" type="text/css" nonce="ZgoZjD9g4Kujx4+ljBovCQ==">\n<link rel="preload" href="/assets/application-6eb5eaa5726150b8135a4fd09118cfd6b29f128586b7fa5019a04f1c740e9193.css" as="style" type="text/css" nonce="ZgoZjD9g4Kujx4+ljBovCQ==">\n<link rel="preload" href="/assets/highlight/themes/white-14ba9f209d5cc375d065606896b08ef3d4dc7be19e5b5800958b390d7ab2bd40.css" as="style" type="text/css" nonce="ZgoZjD9g4Kujx4+ljBovCQ==">\n<link crossorigin="" href="snowplow.trx.gitlab.net" rel="preconnect">\n\n<meta content="IE=edge" http-equiv="X-UA-Compatible">\n<script nonce="QyJNJLXh2Ubce6NGOjbR5g==">\n//<![CDATA[\nvar gl = window.gl || {};\ngl.startup_calls = {"/pages/vuepress/-/refs/master/logs_tree/?format=json\\u0026offset=0":{},"/pages/vuepress/-/blob/master/README.md?format=json\\u0026viewer=rich":{}};\ngl.startup_graphql_calls = null;\n\nif (gl.startup_calls && window.fetch) {\n  Object.keys(gl.startup_calls).forEach(apiCall => {\n   gl.startup_calls[apiCall] = {\n      fetchCall: fetch(apiCall, {\n        // Emulate XHR for Rails AJAX request checks\n        headers: {\n          \'X-Requested-With\': \'XMLHttpRequest\'\n        },\n        // fetch won’t send cookies in older browsers, unless you set the credentials init option.\n        // We set to `same-origin` which is default value in modern browsers.\n        // See https://github.com/whatwg/fetch/pull/585 for more information.\n        credentials: \'same-origin\'\n      })\n    };\n  });\n}\nif (gl.startup_graphql_calls && window.fetch) {\n  const headers = {"X-CSRF-Token":"o/AdY8nCw7TpSxIOx7cEPvL3MK8oyHw+3WOf+cthWFwnC3d7F7ClsNtRiC1j6zStW0rCipxnKjvVMYncFuLITA==","x-gitlab-feature-category":"projects"};\n  const url = `https://gitlab.com/api/graphql`\n\n  const opts = {\n    method: "POST",\n    headers: {\n      "Content-Type": "application/json",\n      ...headers,\n    }\n  };\n\n  gl.startup_graphql_calls = gl.startup_graphql_calls.map(call => ({\n    ...call,\n    fetchCall: fetch(url, {\n      ...opts,\n      credentials: \'same-origin\',\n      body: JSON.stringify(call)\n    })\n  }))\n}\n\n\n//]]>\n</script>\n<meta content="object" property="og:type">\n<meta content="GitLab" property="og:site_name">\n<meta content="GitLab Pages examples / vuepress" property="og:title">\n<meta content="Example VuePress site using GitLab Pages: https://pages.gitlab.io/vuepress" property="og:description">\n<meta content="https://gitlab.com/uploads/-/system/project/avatar/7777404/vuepress.png" property="og:image">\n<meta content="64" property="og:image:width">\n<meta content="64" property="og:image:height">\n<meta content="https://gitlab.com/pages/vuepress" property="og:url">\n<meta content="summary" property="twitter:card">\n<meta content="GitLab Pages examples / vuepress" property="twitter:title">\n<meta content="Example VuePress site using GitLab Pages: https://pages.gitlab.io/vuepress" property="twitter:description">\n<meta content="https://gitlab.com/uploads/-/system/project/avatar/7777404/vuepress.png" property="twitter:image">\n\n<title>GitLab Pages examples / vuepress · GitLab</title>\n<meta content="Example VuePress site using GitLab Pages: https://pages.gitlab.io/vuepress" name="description">\n\n<link rel="shortcut icon" type="image/png" href="/assets/favicon-yellow-bef6823e78fa007bd8a5fd5f432d3e1487e0bd6631717726b5029997f32cecfc.png" id="favicon" data-original-href="/assets/favicon-yellow-bef6823e78fa007bd8a5fd5f432d3e1487e0bd6631717726b5029997f32cecfc.png" />\n<style>\n@keyframes blinking-dot{0%{opacity:1}25%{opacity:0.4}75%{opacity:0.4}100%{opacity:1}}@keyframes blinking-scroll-button{0%{opacity:0.2}50%{opacity:1}100%{opacity:0.2}}@keyframes gl-spinner-rotate{0%{transform:rotate(0)}100%{transform:rotate(360deg)}}body.ui-indigo{ ...
#     'merge_requests': {'url': 'https://gitlab.com/pages/vuepress/-/merge_requests',
#      'html': '<!DOCTYPE html>\n<html class="" lang="en">\n<head prefix="og: http://ogp.me/ns#">\n<meta charset="utf-8">\n<link rel="preload" href="/assets/application_utilities-79bc2841975b0e515219eb7a828208ace79b8c07d0536e809746db7e22deeaab.css" as="style" type="text/css" nonce="ZgoZjD9g4Kujx4+ljBovCQ==">\n<link rel="preload" href="/assets/application-6eb5eaa5726150b8135a4fd09118cfd6b29f128586b7fa5019a04f1c740e9193.css" as="style" type="text/css" nonce="ZgoZjD9g4Kujx4+ljBovCQ==">\n<link rel="preload" href="/assets/highlight/themes/white-14ba9f209d5cc375d065606896b08ef3d4dc7be19e5b5800958b390d7ab2bd40.css" as="style" type="text/css" nonce="ZgoZjD9g4Kujx4+ljBovCQ==">\n<link crossorigin="" href="snowplow.trx.gitlab.net" rel="preconnect">\n\n<meta content="IE=edge" http-equiv="X-UA-Compatible">\n\n<meta content="object" property="og:type">\n<meta content="GitLab" property="og:site_name">\n<meta content="Merge requests · GitLab Pages examples / vuepress" property="og:title">\n<meta content="Example VuePress site using GitLab Pages: https://pages.gitlab.io/vuepress" property="og:description">\n<meta content="https://gitlab.com/uploads/-/system/project/avatar/7777404/vuepress.png" property="og:image">\n<meta content="64" property="og:image:width">\n<meta content="64" property="og:image:height">\n<meta content="https://gitlab.com/pages/vuepress/-/merge_requests" property="og:url">\n<meta content="summary" property="twitter:card">\n<meta content="Merge requests · GitLab Pages examples / vuepress" property="twitter:title">\n<meta content="Example VuePress site using GitLab Pages: https://pages.gitlab.io/vuepress" property="twitter:description">\n<meta content="https://gitlab.com/uploads/-/system/project/avatar/7777404/vuepress.png" property="twitter:image">\n\n<title>Merge requests · GitLab Pages examples / vuepress · GitLab</title>\n<meta content="Example VuePress site using GitLab Pages: https://pages.gitlab.io/vuepress" name="description">\n\n<link rel="shortcut icon" type="image/png" href="/assets/favicon-7901bd695fb93edb07975966062049829afb56cf11511236e61bcf425070e36e.png" id="favicon" data-original-href="/assets/favicon-7901bd695fb93edb07975966062049829afb56cf11511236e61bcf425070e36e.png" />\n<style>\n@keyframes blinking-dot{0%{opacity:1}25%{opacity:0.4}75%{opacity:0.4}100%{opacity:1}}@keyframes blinking-scroll-button{0%{opacity:0.2}50%{opacity:1}100%{opacity:0.2}}@keyframes gl-spinner-rotate{0%{transform:rotate(0)}100%{transform:rotate(360deg)}}body.ui-indigo{--gl-theme-accent: #6666c4}body.ui-indigo .navbar-gitlab{background-color:#292961}body.ui-indigo .navbar-gitlab .navbar-collapse{color:#d1d1f0}body.ui-indigo .navbar-gitlab .container-fluid .navbar-toggler{border-left:1px solid #6868b9;color:#d1d1f0}body.ui-indigo .navbar-gitlab .navbar-sub-nav>li>a:hover,body.ui-indigo .navbar-gitlab .navbar-sub-nav>li>a:focus,body.ui-indigo .navbar-gitlab .navbar-sub-nav>li>button:hover,body.ui-indigo .navbar-gitlab .navbar-sub-nav>li>button:focus,body.ui-indigo .navbar-gitlab .navbar-nav>li>a:hover,body.ui-indigo .navbar-gitlab .navbar-nav>li>a:focus,body.ui-indigo .navbar-gitlab .navbar-nav>li>button:hover,body.ui-indigo .navbar-gitlab .navbar-nav>li>button:focus{background-color:rgba(209,209,240,0.2)}body.ui-indigo .navbar-gitlab .navbar-sub-nav>li.active>a,body.ui-indigo .navbar-gitlab .navbar-sub-nav>li.active>button,body.ui-indigo .navbar-gitlab .navbar-sub-nav>li.dropdown.show>a,body.ui-indigo .navbar-gitlab .navbar-sub-nav>li.dropdown.show>button,body.ui-indigo .navbar-gitlab .navbar-nav>li.active>a,body.ui-indigo .navbar-gitlab .navbar-nav>li.active>button,body.ui-indigo .navbar-gitlab .navbar-nav>li.dropdown.show>a,body.ui-indigo .navbar-gitlab .navbar-nav>li.dropdown.show>button{color:#292961;background-color:#fff}body.ui-indigo .navbar-gitlab .navbar-sub-nav>li.line-separator,body.ui-indigo .navbar-gitlab .navbar-nav>li.line-separator{border-left:1px solid rgba(209,209,240,0.2)}body.ui-indigo .navbar-gitlab .navbar-sub-nav{col ...

# %%
with open('gitlab.json', 'w') as f:
    json.dump(all_data, f)
