# %%
# !pip install python-gitlab
# Docs: https://python-gitlab.readthedocs.io/en/stable/api-usage.html
# !pip install beautifulsoup4
# Docs: https://www.crummy.com/software/BeautifulSoup/bs4/doc/
# Out:
# Requirement already satisfied: python-gitlab in c:\users\jonathan\anaconda3\lib\site-packages (3.2.0)
# Requirement already satisfied: requests>=2.25.0 in c:\users\jonathan\anaconda3\lib\site-packages (from python-gitlab) (2.26.0)
# Requirement already satisfied: requests-toolbelt>=0.9.1 in c:\users\jonathan\anaconda3\lib\site-packages (from python-gitlab) (0.9.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\jonathan\anaconda3\lib\site-packages (from requests>=2.25.0->python-gitlab) (3.2)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\jonathan\anaconda3\lib\site-packages (from requests>=2.25.0->python-gitlab) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\jonathan\anaconda3\lib\site-packages (from requests>=2.25.0->python-gitlab) (1.26.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\jonathan\anaconda3\lib\site-packages (from requests>=2.25.0->python-gitlab) (2021.10.8)
# Requirement already satisfied: beautifulsoup4 in c:\users\jonathan\anaconda3\lib\site-packages (4.10.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\jonathan\anaconda3\lib\site-packages (from beautifulsoup4) (2.2.1)

# %%
#Imports in one place to not cloud up work
import requests
import gitlab
from bs4 import BeautifulSoup
import functools
import re
import time

# %%
#https://gitlab.com/explore/projects/starred
# Get top n starred projects. 
# Gitlab API does not support this, so we must use web-scraping

# Caching to avoid rate limiting
@functools.cache
def get_starred_projects_html(page_num):
    return requests.get(f"https://gitlab.com/explore/projects/starred?sort=stars_desc&page={page_num}")

# %%
projects = []
for page in range(1, 50):  # 50 is the max page
    r = get_starred_projects_html(page)
    good_soup = BeautifulSoup(r.text, 'html.parser')  # https://www.youtube.com/watch?v=gkXzeZ0KE5Q
    projects.extend(good_soup.find_all("li", {"class": 'project-row'}))
    time.sleep(0.5)  # Dont get rate-limited by gitlab

# %%
# Turn div into project dict
non_number_re = re.compile('[^0-9]')
def extract_proj_details(proj):
    return {
        'name': proj.find('span', {'class': 'project-name'}).text,
        'namespace': proj.find('span', {'class': 'namespace-name'}).text[:-3].strip(),
        'url': proj.find('a').attrs['href'],
        # Following are possible to get from here but better to get from api as they are not always in html
#             'stars': int(non_number_re.sub('', proj.find('a', {'title': 'Stars'}).text)),
#             'forks': int(non_number_re.sub('', proj.find('a', {'title': 'Forks'}).text)),
    }
extract_proj_details(projects[0])
# Out:
# {'name': 'GitLab FOSS',
#  'namespace': 'GitLab.org',
#  'url': '/gitlab-org/gitlab-foss'}

# %%
top_projects = [extract_proj_details(proj) for proj in projects]
len(top_projects), top_projects[:5]
# Out:
# (400,
#  [{'name': 'GitLab FOSS',
#    'namespace': 'GitLab.org',
#    'url': '/gitlab-org/gitlab-foss'},
#   {'name': 'GitLab', 'namespace': 'GitLab.org', 'url': '/gitlab-org/gitlab'},
#   {'name': 'inkscape', 'namespace': 'Inkscape', 'url': '/inkscape/inkscape'},
#   {'name': 'OpenRGB',
#    'namespace': 'Adam Honse',
#    'url': '/CalcProgrammer1/OpenRGB'},
#   {'name': 'gitlab-runner',
#    'namespace': 'GitLab.org',
#    'url': '/gitlab-org/gitlab-runner'}])

# %%
import gitlab

# anonymous read-only access for public resources (GitLab.com)
gl = gitlab.Gitlab()
gl

# %%
def extract_gl_data_from_project(proj):
    gl_proj = gl.projects.get(proj['url'][1:])
    proj_data = gl_proj.attributes
    groups = gl_proj.groups.list()
    proj_data['groups'] = [group.attributes for group in gl_proj.groups.list(all=True)]
    proj_data['languages'] = gl_proj.languages()
    proj_data['top_20_repository_contibutors'] = gl_proj.repository_contributors(per_page=20, order_by='commits', sort='desc')
    
    # get branch/commit/tag counts through requests and bs4 as its not in gitlab api
    proj_page_text = requests.get(f'https://gitlab.com{proj["url"]}').text
    good_soup = BeautifulSoup(proj_page_text, 'html.parser')
    soup_stats = good_soup.find('nav', {'class': 'project-stats'})
    soup_stats = [x.text for x in soup_stats.find_all('strong', {'class': 'project-stat-value'})]
    for stat_name, stat_value in zip(['commits', 'branches', 'tags', 'files', 'storage', 'releases'], soup_stats):
        proj_data[f'from_page_stats_{stat_name}'] = stat_value
    
    return proj_data

# %%
top_proj_data = [extract_gl_data_from_project(proj) for proj in top_projects[:50]]

# %%
len(top_proj_data), top_proj_data[-5:]
# Out:
# (50,
#  [{'id': 7898047,
#    'description': "Wireshark's official Git repository.",
#    'name': 'wireshark',
#    'name_with_namespace': 'Wireshark Foundation / wireshark',
#    'path': 'wireshark',
#    'path_with_namespace': 'wireshark/wireshark',
#    'created_at': '2018-08-10T20:58:07.700Z',
#    'default_branch': 'master',
#    'tag_list': ['packet capture', 'protocol analysis', 'tshark', 'wireshark'],
#    'topics': ['packet capture', 'protocol analysis', 'tshark', 'wireshark'],
#    'ssh_url_to_repo': 'git@gitlab.com:wireshark/wireshark.git',
#    'http_url_to_repo': 'https://gitlab.com/wireshark/wireshark.git',
#    'web_url': 'https://gitlab.com/wireshark/wireshark',
#    'readme_url': 'https://gitlab.com/wireshark/wireshark/-/blob/master/README.md',
#    'avatar_url': 'https://gitlab.com/uploads/-/system/project/avatar/7898047/wsicon180.png',
#    'forks_count': 551,
#    'star_count': 453,
#    'last_activity_at': '2022-03-18T17:24:49.215Z',
#    'namespace': {'id': 3421856,
#     'name': 'Wireshark Foundation',
#     'path': 'wireshark',
#     'kind': 'group',
#     'full_path': 'wireshark',
#     'parent_id': None,
#     'avatar_url': '/uploads/-/system/group/avatar/3421856/wsicon180.png',
#     'web_url': 'https://gitlab.com/groups/wireshark'},
#    'groups': [{'id': 3421856,
#      'web_url': 'https://gitlab.com/groups/wireshark',
#      'name': 'Wireshark Foundation',
#      'avatar_url': 'https://gitlab.com/uploads/-/system/group/avatar/3421856/wsicon180.png',
#      'full_name': 'Wireshark Foundation',
#      'full_path': 'wireshark',
#      'project_id': 7898047}],
#    'languages': {'C': 93.55,
#     'C++': 3.11,
#     'Objective-C': 1.11,
#     'Python': 1.09,
#     'Perl': 0.41},
#    'top_20_repository_contibutors': [{'name': 'João Valverde',
#      'email': 'j@v6e.pt',
#      'commits': 439,
#      'additions': 0,
#      'deletions': 0},
#     {'name': 'John Thacker',
#      'email': 'johnthacker@gmail.com',
#      'commits': 228,
#      'additions': 0,
#      'deletions': 0},
#     {'name': 'Gerald Combs',
#      'email': 'gerald@wireshark.org',
#      'commits': 225,
#      'additions': 0,
#      'deletions': 0},
#     {'name': 'Alexis La Goutte',
#      'email': 'alexis.lagoutte@gmail.com',
#      'commits': 90,
#      'additions': 0,
#      'deletions': 0},
#     {'name': 'Guy Harris',
#      'email': 'gharris@sonic.net',
#      'commits': 71,
#      'additions': 0,
#      'deletions': 0},
#     {'name': 'Martin Mathieson',
#      'email': 'martin.r.mathieson@googlemail.com',
#      'commits': 68,
#      'additions': 0,
#      'deletions': 0},
#     {'name': 'Dr. Lars Völker',
#      'email': 'lars.voelker@technica-engineering.de',
#      'commits': 68,
#      'additions': 0,
#      'deletions': 0},
#     {'name': 'Stig Bjørlykke',
#      'email': 'stig@bjorlykke.org',
#      'commits': 39,
#      'additions': 0,
#      'deletions': 0},
#     {'name': 'Pascal Quantin',
#      'email': 'pascal@wireshark.org',
#      'commits': 37,
#      'additions': 0,
#      'deletions': 0},
#     {'name': 'Jaap Keuter',
#      'email': 'jaap.keuter@xs4all.nl',
#      'commits': 35,
#      'additions': 0,
#      'deletions': 0},
#     {'name': 'Chuck Craft',
#      'email': 'bubbasnmp@gmail.com',
#      'commits': 33,
#      'additions': 0,
#      'deletions': 0},
#     {'name': 'Uli Heilmeier',
#      'email': 'uh@heilmeier.eu',
#      'commits': 31,
#      'additions': 0,
#      'deletions': 0},
#     {'name': 'Dario Lombardo',
#      'email': 'lomato@gmail.com',
#      'commits': 27,
#      'additions': 0,
#      'deletions': 0},
#     {'name': 'Roman Volkov',
#      'email': 'volkoff_roman@ukr.net',
#      'commits': 27,
#      'additions': 0,
#      'deletions': 0},
#     {'name': 'Anders Broman',
#      'email': 'anders.broman@ericsson.com',
#      'commits': 25,
#      'additions': 0,
#      'deletions': 0},
#     {'name': 'Moshe Kaplan',
#      'email': 'me@moshekaplan.com',
#      'commits': 22,
#      'additions': 0,
#      'deletions': 0},
#     {'name': 'Evan Huus',
#      'email': 'eapache@gmail.com',
#      'commits': 21,
#      'additions': 0,
#      'deletions': 0},
#     {'name': 'Roland Knall',
#      'email': 'rknall@gmail.com',
#      'commits': 18,
#      'additions': 0,
#      'deletions': 0},
#     {'name': 'Joakim Karlsson',
#      'email': 'oakimk@gmail.com',
#      'commits': 17,
#      'additions': 0,
#      'deletions': 0},
#     {'name': 'j.novak@netsystem.cz',
#      'email': 'j.novak@netsystem.cz',
#      'commits': 15,
#      'additions': 0,
#      'deletions': 0}],
#    'from_page_stats_commits': '83,784',
#    'from_page_stats_branches': '28',
#    'from_page_stats_tags': '835',
#    'from_page_stats_files': '98 MB',
#    'from_page_stats_storage': '755.9 GB'},
#   {'id': 6947723,
#    'description': 'Shinobi Pro - The Next Generation in Open-Source Video Management Software with support for over 6000 IP and USB Cameras http://shinobi.video\r\n',
#    'name': 'Shinobi',
#    'name_with_namespace': 'Shinobi Systems / Shinobi',
#    'path': 'Shinobi',
#    'path_with_namespace': 'Shinobi-Systems/Shinobi',
#    'created_at': '2018-06-08T02:05:05.745Z',
#    'default_branch': 'master',
#    'tag_list': [],
#    'topics': [],
#    'ssh_url_to_repo': 'git@gitlab.com:Shinobi-Systems/Shinobi.git',
#    'http_url_to_repo': 'https://gitlab.com/Shinobi-Systems/Shinobi.git',
#    'web_url': 'https://gitlab.com/Shinobi-Systems/Shinobi',
#    'readme_url': 'https://gitlab.com/Shinobi-Systems/Shinobi/-/blob/master/README.md',
#    'avatar_url': 'https://gitlab.com/uploads/-/system/project/avatar/6947723/mstile-150x150.png',
#    'forks_count': 224,
#    'star_count': 428,
#    'last_activity_at': '2022-03-15T16:49:13.155Z',
#    'namespace': {'id': 3033038,
#     'name': 'Shinobi Systems',
#     'path': 'Shinobi-Systems',
#     'kind': 'group',
#     'full_path': 'Shinobi-Systems',
#     'parent_id': None,
#     'avatar_url': '/uploads/-/system/group/avatar/3033038/mstile-150x150.png',
#     'web_url': 'https://gitlab.com/groups/Shinobi-Systems'},
#    'groups': [{'id': 3033038,
#      'web_url': 'https://gitlab.com/groups/Shinobi-Systems',
#      'name': 'Shinobi Systems',
#      'avatar_url': 'https://gitlab.com/uploads/-/system/group/avatar/3033038/mstile-150x150.png',
#      'full_name': 'Shinobi Systems',
#      'full_path': 'Shinobi-Systems',
#      'project_id': 6947723}],
#    'languages': {'JavaScript': 73.62,
#     'CSS': 8.53,
#     'HTML': 6.72,
#     'SCSS': 5.77,
#     'Shell': 2.96},
#    'top_20_repository_contibutors': [{'name': 'Moe',
#      'email': 'github@m03.ca',
#      'commits': 1555,
#      'additions': 0,
#      'deletions': 0},
#     {'name': 'Mike Hurley',
#      'email': 'mhurley@technokami.com',
#      'commits': 45,
#      'additions': 0,
#      'deletions': 0},
#     {'name': 'DewGew',
#      'email': 'pierlar@hotmail.com',
#      'commits': 45,
#      'additions': 0,
#      'deletions': 0},
#     {'name': 'JordanGeoghegan',
#      'email': 'jordan@geoghegan.ca',
#      'commits': 20,
#      'additions': 0,
#      'deletions': 0},
#     {'name': 'Ian Rubado',
#      'email': 'irubado@lavarok.com',
#      'commits': 19,
#      'additions': 0,
#      'deletions': 0},
#     {'name': 'dennis.cartier',
#      'email': 'dennis.cartier@gmail.com',
#      'commits': 16,
#      'additions': 0,
#      'deletions': 0},
#     {'name': 'Austin Lakeman',
#      'email': 'lakeman.aust@gmail.com',
#      'commits': 10,
#      'additions': 0,
#      'deletions': 0},
#     {'name': 'Moe',
#      'email': 'gitlab@m03.ca',
#      'commits': 10,
#      'additions': 0,
#      'deletions': 0},
#     {'name': 'Levent K',
#      'email': 'dermodmaster@googlemail.com',
#      'commits': 5,
#      'additions': 0,
#      'deletions': 0},
#     {'name': 'dapowers87',
#      'email': 'dapowers87@gmail.com',
#      'commits': 5,
#      'additions': 0,
#      'deletions': 0},
#     {'name': 'Adam Radovits',
#      'email': 'adamradovits12@hotmail.com',
#      'commits': 5,
#      'additions': 0,
#      'deletions': 0},
#     {'name': 'zero',
#      'email': 'zero@phantom.industries',
#      'commits': 5,
#      'additions': 0,
#      'deletions': 0},
#     {'name': 'Elad Bar',
#      'email': 'elad.bar@hotmail.com',
#      'commits': 4,
#      'additions': 0,
#      'deletions': 0},
#     {'name': 'Levent Koch',
#      'email': 'l.koch@mittwald.de',
#      'commits': 4,
#      'additions': 0,
#      'deletions': 0},
#     {'name': 'Sebastián Felipe',
#      'email': 'sebastian.torres.garfe@gmail.com',
#      'commits': 4,
#      'additions': 0,
#      'deletions': 0},
#     {'name': 'Jarrod Connolly',
#      'email': 'Jarrod.Connolly@cewa.edu.au',
#      'commits': 3,
#      'additions': 0,
#      'deletions': 0},
#     {'name': 'Mitch Ross',
#      'email': 'mitchross09@gmail.com',
#      'commits': 3,
#      'additions': 0,
#      'deletions': 0},
#     {'name': 'Peeter Normak',
#      'email': 'peeter.normak@eesti.ee',
#      'commits': 3,
#      'additions': 0,
#      'deletions': 0},
#     {'name': 'Johnny Casey',
#      'email': 'jjcasey@pobox.com',
#      'commits': 2,
#      'additions': 0,
#      'deletions': 0},
#     {'name': 'Dave Hayes',
#      'email': 'dave@dream-tech.com',
#      'commits': 2,
#      'additions': 0,
#      'deletions': 0}],
#    'from_page_stats_commits': '2,106',
#    'from_page_stats_branches': '41',
#    'from_page_stats_tags': '4',
#    'from_page_stats_files': '3.4 MB',
#    'from_page_stats_storage': '86.3 MB',
#    'from_page_stats_releases': '3'},
#   {'id': 4180516,
#    'description': 'A modular documentation site generator. Designed for users of Asciidoctor.\r\n\r\nThis repository hosts the core software components and documentation for Antora.\r\n\r\nhttps://antora.org',
#    'name': 'Antora',
#    'name_with_namespace': 'Antora / Antora',
#    'path': 'antora',
#    'path_with_namespace': 'antora/antora',
#    'created_at': '2017-09-19T00:07:30.713Z',
#    'default_branch': 'main',
#    'tag_list': ['Antora',
#     'AsciiDoc',
#     'Asciidoctor',
#     'CLI',
#     'documentation',
#     'static site generator'],
#    'topics': ['Antora',
#     'AsciiDoc',
#     'Asciidoctor',
#     'CLI',
#     'documentation',
#     'static site generator'],
#    'ssh_url_to_repo': 'git@gitlab.com:antora/antora.git',
#    'http_url_to_repo': 'https://gitlab.com/antora/antora.git',
#    'web_url': 'https://gitlab.com/antora/antora',
#    'readme_url': 'https://gitlab.com/antora/antora/-/blob/main/README.adoc',
#    'avatar_url': 'https://gitlab.com/uploads/-/system/project/avatar/4180516/antora-gitlab.png',
#    'forks_count': 165,
#    'star_count': 422,
#    'last_activity_at': '2022-03-16T09:05:30.459Z',
#    'namespace': {'id': 1984945,
#     'name': 'Antora',
#     'path': 'antora',
#     'kind': 'group',
#     'full_path': 'antora',
#     'parent_id': None,
#     'avatar_url': '/uploads/-/system/group/avatar/1984945/antora-gitlab.png',
#     'web_url': 'https://gitlab.com/groups/antora'},
#    'groups': [{'id': 1984945,
#      'web_url': 'https://gitlab.com/groups/antora',
#      'name': 'Antora',
#      'avatar_url': 'https://gitlab.com/uploads/-/system/group/avatar/1984945/antora-gitlab.png',
#      'full_name': 'Antora',
#      'full_path': 'antora',
#      'project_id': 4180516}],
#    'languages': {'JavaScript': 99.72, 'Shell': 0.28},
#    'top_20_repository_contibutors': [{'name': 'Dan Allen',
#      'email': 'dan@opendevise.com',
#      'commits': 1619,
#      'additions': 0,
#      'deletions': 0},
#     {'name': 'Sarah White',
#      'email': 'sarah@opendevise.com',
#      'commits': 303,
#      'additions': 0,
#      'deletions': 0},
#     {'name': 'David Jencks',
#      'email': 'djencks@apache.org',
#      'commits': 21,
#      'additions': 0,
#      'deletions': 0},
#     {'name': 'Sarah White',
#      'email': 'graphitefriction@gmail.com',
#      'commits': 7,
#      'additions': 0,
#      'deletions': 0},
#     {'name': 'Daniel Mulholland',
#      'email': 'dan.mulholland@gmail.com',
#      'commits': 6,
#      'additions': 0,
#      'deletions': 0},
#     {'name': 'Guillaume Grossetie',
#      'email': 'ggrossetie@gmail.com',
#      'commits': 5,
#      'additions': 0,
#      'deletions': 0},
#     {'name': 'Alexander Schwartz',
#      'email': 'alexander.schwartz@gmx.net',
#      'commits': 5,
#      'additions': 0,
#      'deletions': 0},
#     {'name': 'Ben Walding',
#      'email': 'bwalding@cloudbees.com',
#      'commits': 3,
#      'additions': 0,
#      'deletions': 0},
#     {'name': 'James Elliott',
#      'email': 'james@deepsymmetry.org',
#      'commits': 3,
#      'additions': 0,
#      'deletions': 0},
#     {'name': 'Antonio',
#      'email': 'zolotuhin87@gmail.com',
#      'commits': 3,
#      'additions': 0,
#      'deletions': 0},
#     {'name': 'Matthew Setter',
#      'email': 'matthew@matthewsetter.com',
#      'commits': 2,
#      'additions': 0,
#      'deletions': 0},
#     {'name': 'François Violette',
#      'email': 'francoisviolette@gmail.com',
#      'commits': 2,
#      'additions': 0,
#      'deletions': 0},
#     {'name': 'Ben Franske',
#      'email': 'ben.mm@franske.com',
#      'commits': 1,
#      'additions': 0,
#      'deletions': 0},
#     {'name': 'Nimrod Wandera',
#      'email': 'wanderanimrod@gmail.com',
#      'commits': 1,
#      'additions': 0,
#      'deletions': 0},
#     {'name': 'Ronny Trommer',
#      'email': 'ronny@no42.org',
#      'commits': 1,
#      'additions': 0,
#      'deletions': 0},
#     {'name': 'Vladimir Markiev',
#      'email': 'grolribasi@gmail.com',
#      'commits': 1,
#      'additions': 0,
#      'deletions': 0},
#     {'name': 'Juracy Filho',
#      'email': 'juracy@gmail.com',
#      'commits': 1,
#      'additions': 0,
#      'deletions': 0},
#     {'name': 'Sturt Ison',
#      'email': 'sturt.ison@gmail.com',
#      'commits': 1,
#      'additions': 0,
#      'deletions': 0},
#     {'name': 'Aarno Aukia',
#      'email': 'aarno.aukia@vshn.ch',
#      'commits': 1,
#      'additions': 0,
#      'deletions': 0},
#     {'name': 'George Gastaldi',
#      'email': 'gegastaldi@gmail.com',
#      'commits': 1,
#      'additions': 0,
#      'deletions': 0}],
#    'from_page_stats_commits': '4,237',
#    'from_page_stats_branches': '7',
#    'from_page_stats_tags': '67',
#    'from_page_stats_files': '6.6 MB',
#    'from_page_stats_storage': '829.1 MB'},
#   {'id': 2712276,
#    'description': "Dropzone is an easy to use drag'n'drop library. It supports image previews and shows nice progress bars. http://www.dropzonejs.com",
#    'name': 'Dropzone',
#    'name_with_namespace': 'Matias Meno / Dropzone',
#    'path': 'dropzone',
#    'path_with_namespace': 'meno/dropzone',
#    'created_at': '2017-02-15T20:15:35.648Z',
#    'default_branch': 'deprecated',
#    'tag_list': [],
#    'topics': [],
#    'ssh_url_to_repo': 'git@gitlab.com:meno/dropzone.git',
#    'http_url_to_repo': 'https://gitlab.com/meno/dropzone.git',
#    'web_url': 'https://gitlab.com/meno/dropzone',
#    'readme_url': 'https://gitlab.com/meno/dropzone/-/blob/deprecated/README.md',
#    'avatar_url': 'https://gitlab.com/uploads/-/system/project/avatar/2712276/dropzone-logo.png',
#    'forks_count': 135,
#    'star_count': 403,
#    'last_activity_at': '2021-09-13T11:40:28.868Z',
#    'namespace': {'id': 762228,
#     'name': 'Matias Meno',
#     'path': 'meno',
#     'kind': 'user',
#     'full_path': 'meno',
#     'parent_id': None,
#     'avatar_url': 'https://secure.gravatar.com/avatar/ce44e57e4bc9b51f9692e17bae6319e7?s=80&d=identicon',
#     'web_url': 'https://gitlab.com/meno'},
#    'groups': [],
#    'languages': {'JavaScript': 80.7,
#     'HTML': 9.82,
#     'CSS': 9.38,
#     'Makefile': 0.09,
#     'Shell': 0.01},
#    'top_20_repository_contibutors': [{'name': 'Matias Meno',
#      'email': 'm@tias.me',
#      'commits': 1,
#      'additions': 0,
#      'deletions': 0}],
#    'from_page_stats_commits': '1',
#    'from_page_stats_branches': '12',
#    'from_page_stats_tags': '9',
#    'from_page_stats_files': '5.4 MB',
#    'from_page_stats_storage': '33.6 MB',
#    'from_page_stats_releases': '6'},
#   {'id': 4815250,
#    'description': '',
#    'name': 'mutt',
#    'name_with_namespace': 'Mutt Project / mutt',
#    'path': 'mutt',
#    'path_with_namespace': 'muttmua/mutt',
#    'created_at': '2017-12-04T18:06:30.678Z',
#    'default_branch': 'master',
#    'tag_list': [],
#    'topics': [],
#    'ssh_url_to_repo': 'git@gitlab.com:muttmua/mutt.git',
#    'http_url_to_repo': 'https://gitlab.com/muttmua/mutt.git',
#    'web_url': 'https://gitlab.com/muttmua/mutt',
#    'readme_url': 'https://gitlab.com/muttmua/mutt/-/blob/master/README',
#    'avatar_url': 'https://gitlab.com/uploads/-/system/project/avatar/4815250/muttlogo.png',
#    'forks_count': 101,
#    'star_count': 388,
#    'last_activity_at': '2022-03-15T20:53:56.814Z',
#    'namespace': {'id': 2261647,
#     'name': 'Mutt Project',
#     'path': 'muttmua',
#     'kind': 'user',
#     'full_path': 'muttmua',
#     'parent_id': None,
#     'avatar_url': '/uploads/-/system/user/avatar/1833394/avatar.png',
#     'web_url': 'https://gitlab.com/muttmua'},
#    'groups': [],
#    'languages': {'C': 89.72,
#     'M4': 5.41,
#     'Objective-C': 1.06,
#     'Perl': 0.97,
#     'C++': 0.92},
#    'top_20_repository_contibutors': [{'name': 'Kevin McCarthy',
#      'email': 'kevin@8t8.us',
#      'commits': 1495,
#      'additions': 0,
#      'deletions': 0},
#     {'name': 'Vincent Lefevre',
#      'email': 'vincent@vinc17.net',
#      'commits': 142,
#      'additions': 0,
#      'deletions': 0},
#     {'name': 'Olaf Hering',
#      'email': 'olaf@aepfle.de',
#      'commits': 32,
#      'additions': 0,
#      'deletions': 0},
#     {'name': 'Vsevolod Volkov',
#      'email': 'vvv@mutt.org.ua',
#      'commits': 22,
#      'additions': 0,
#      'deletions': 0},
#     {'name': 'Remco Rĳnders',
#      'email': 'remco@webconquest.com',
#      'commits': 22,
#      'additions': 0,
#      'deletions': 0},
#     {'name': 'Tamotsu TAKAHASHI',
#      'email': 'ttakah@lapis.plala.or.jp',
#      'commits': 16,
#      'additions': 0,
#      'deletions': 0},
#     {'name': 'Damien Riegel',
#      'email': 'damien.riegel@gmail.com',
#      'commits': 16,
#      'additions': 0,
#      'deletions': 0},
#     {'name': 'Grzegorz Szymaszek',
#      'email': 'gszymaszek@short.pl',
#      'commits': 15,
#      'additions': 0,
#      'deletions': 0},
#     {'name': 'David Champion',
#      'email': 'dgc@bikeshed.us',
#      'commits': 14,
#      'additions': 0,
#      'deletions': 0},
#     {'name': 'Petr Písař',
#      'email': 'petr.pisar@atlas.cz',
#      'commits': 11,
#      'additions': 0,
#      'deletions': 0},
#     {'name': 'Ivan Vilata i Balaguer',
#      'email': 'ivan@selidor.net',
#      'commits': 10,
#      'additions': 0,
#      'deletions': 0},
#     {'name': 'Maxim Tarasov',
#      'email': 'mu@magi.net.ru',
#      'commits': 9,
#      'additions': 0,
#      'deletions': 0},
#     {'name': 'Richard Russon',
#      'email': 'rich@flatcap.org',
#      'commits': 7,
#      'additions': 0,
#      'deletions': 0},
#     {'name': 'Helge Kreutzmann',
#      'email': 'debian@helgefjell.de',
#      'commits': 5,
#      'additions': 0,
#      'deletions': 0},
#     {'name': 'Werner Koch',
#      'email': 'wk@gnupg.org',
#      'commits': 5,
#      'additions': 0,
#      'deletions': 0},
#     {'name': 'Morten Bo Johansen',
#      'email': 'mjb@spamcop.net',
#      'commits': 5,
#      'additions': 0,
#      'deletions': 0},
#     {'name': 'Eike Rathke',
#      'email': 'erack@erack.de',
#      'commits': 4,
#      'additions': 0,
#      'deletions': 0},
#     {'name': 'William Yardley',
#      'email': 'wyardley@users.noreply.github.com',
#      'commits': 4,
#      'additions': 0,
#      'deletions': 0},
#     {'name': 'Fabian Groffen',
#      'email': 'grobian@gentoo.org',
#      'commits': 4,
#      'additions': 0,
#      'deletions': 0},
#     {'name': 'David Champion',
#      'email': 'dgc@c13.us',
#      'commits': 4,
#      'additions': 0,
#      'deletions': 0}],
#    'from_page_stats_commits': '8,222',
#    'from_page_stats_branches': '3',
#    'from_page_stats_tags': '209',
#    'from_page_stats_files': '6.4 MB',
#    'from_page_stats_storage': '1.3 GB'}])
